# %% [markdown]
# <a href="https://colab.research.google.com/github/Yok3712/Chadtech/blob/main/Copie_de_Bienvenue_dans_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EMMANUEL EBENEZER YOKORDJE**
#   **PAIR CODING AND FIRST ASSIGNEMENT**

# %% [markdown]
# Question 1

# %%
# Question 1

list1 = [1, 2, 3, 4, 5]
list2 = [10, 15, 20, 25, 30]

new_list = []

for num in list1:
    if num % 2 != 0:
        new_list.append(num)

for num in list2:
    if num % 2 == 0:
        new_list.append(num)

print(new_list)
# Out:
# [1, 3, 5, 10, 20, 30]

# %% [markdown]
# Question 2

# %%
number = input("Enter a number: ")

number = int(number)

count = 0

while number != 0:
    number = number // 10
    count += 1

print("The number of digits is:", count)
# Out:
# Enter a number: 15
# The number of digits is: 2

# %% [markdown]
# Question 3

# %%
def calculate_result(num1, num2):
    # Calculate the product of the two numbers
    product = num1 * num2

    # Check if the product is less than or equal to 1000
    if product <= 1000:
        return product
    else:
        # If the product is greater than 1000, return the sum
        return num1 + num2

num1 = int(input("Enter the first integer: "))
num2 = int(input("Enter the second integer: "))

result = calculate_result(num1, num2)
print("The result is:", result)
# Out:
# Enter the first integer: 152
# Enter the second integer: 152
# The result is: 304

# %% [markdown]
# Question 4

# %%
sample_list = [15, 20, 30, 20, 40, 50, 20, 65]
# Item to remove
item_to_remove = 20
# Remove all occurrences of item_to_remove from sample_list
sample_list = [item for item in sample_list if item != item_to_remove]
# Print the updated list
print("Updated list:", sample_list)
# Out:
# Updated list: [15, 30, 40, 50, 65]

# %% [markdown]
# Question 5

# %%
sample_tuple = (11, 22, 33, 44, 55, 66)
# Elements to copy
elements_to_copy = (22, 66)
# Create a new tuple with the specified elements
new_tuple = tuple([item for item in sample_tuple if item in elements_to_copy])

print("New tuple:", new_tuple)
# Out:
# New tuple: (22, 66)

# %% [markdown]
# Question 6

# %%
# Original dictionary
sample_dict = {
    "name": "Kelly",
    "age": 25,
    "salary": 8000,
    "city": "New York"
}

# Keys to extract
keys_to_extract = ["name", "salary"]

# Create a new dictionary by extracting the specified keys
new_dict = {key: sample_dict[key] if key in sample_dict else None for key in keys_to_extract}

# Print the new dictionary
print("New dictionary:", new_dict)
# Out:
# New dictionary: {'name': 'Kelly', 'salary': 8000}

# %% [markdown]
# Question 7

# %%
class Vehicle:
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
my_vehicle = Vehicle(200, 15000)
print(f"Max Speed: {my_vehicle.max_speed}, Mileage: {my_vehicle.mileage}")
# Out:
# Max Speed: 200, Mileage: 15000

# %% [markdown]
# Question 8

# %%
class Vehicle:
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

    def fare(self, seating_capacity):
        return seating_capacity * 100

class Bus(Vehicle):
    def __init__(self, max_speed, mileage, seating_capacity=50):
        super().__init__(max_speed, mileage)
        self.seating_capacity = seating_capacity

    def fare(self):
        base_fare = super().fare(self.seating_capacity)
        maintenance_charge = base_fare * 0.10
        total_fare = base_fare + maintenance_charge
        return total_fare

# Example usage
my_bus = Bus(120, 20000)
print(f"Total Bus Fare: {my_bus.fare()}")  # Expected result: 5500
# Out:
# Total Bus Fare: 5500.0

# %% [markdown]
# Question 9

# %%
import json

sampleJson = '{"key1": "value1", "key2": "value2"}'

# Parse the JSON
data = json.loads(sampleJson)

print("The value of key2 is:", data['key2'])
# Out:
# The value of key2 is: value2

# %% [markdown]
# Question 10

# %%
import json

sampleJson = {"id": 2, "name": "value2", "age": 30}

# Sort the JSON data by keys
sorted_json = dict(sorted(sampleJson.items()))

# Write the sorted JSON data to a file
with open('sorted_sample.json', 'w') as file:
    json.dump(sorted_json, file, indent=4)

# Print the sorted JSON data
print(json.dumps(sorted_json, indent=4))
# Out:
# {
#     "age": 30,
#     "id": 2,
#     "name": "value2"
# }

# %% [markdown]
# **First** **assignement**

# %%
def calculate_bmi(weight, height):
    return weight / (height ** 2)

def get_health_assessment(bmi):
    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi <= 24.9:
        return "Normal weight"
    elif 25 <= bmi <= 29.9:
        return "Overweight"
    else:
        return "Obesity"

def get_positive_float(prompt):
    while True:
        try:
            value = float(input(prompt))
            if value > 0:
                return value
            else:
                print("Error: Please enter a positive value.")
        except ValueError:
            print("Error: Invalid input. Please enter a number.")

def main():
    print("BMI Calculator")

    weight = get_positive_float("Enter your weight in kilograms: ")
    height = get_positive_float("Enter your height in meters: ")

    bmi = calculate_bmi(weight, height)
    assessment = get_health_assessment(bmi)

    print(f"Your BMI is {bmi:.2f}. You are categorized as {assessment}.")

if __name__ == "__main__":
    main()
# Out:
# BMI Calculator
# Enter your weight in kilograms: 63
# Enter your height in meters: 1.82
# Your BMI is 19.02. You are categorized as Normal weight.
